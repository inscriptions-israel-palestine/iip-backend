# %%
# %load_ext autoreload
# %autoreload 2
from iip_search.epidoc_parser import EpidocParser

# %%
parser = EpidocParser("./epidoc-files/ahma0001.xml")
# Out:
# INFO: 2023-08-27 18:27:19,820 Getting form taxonomy...
# INFO: 2023-08-27 18:27:19,821 Getting genre taxonomy...
# INFO: 2023-08-27 18:27:19,822 Getting materials taxonomy...
# INFO: 2023-08-27 18:27:19,822 Getting preservation taxonomy...
# INFO: 2023-08-27 18:27:19,823 Getting religion taxonomy...
# INFO: 2023-08-27 18:27:19,823 Getting writing taxonomy...
# INFO: 2023-08-27 18:27:19,823 Attempting to parse ./epidoc-files/ahma0001.xml.

# %%
print(parser.get_figures())
# Out:
# [{'name': 'grapevine and vase', 'locus': 'upper panel of the architrave'}]

# %%
NAMESPACES = {"tei": "http://www.tei-c.org/ns/1.0"}

# %%
from lxml import etree

# %%
tree = etree.parse("../epidoc-files/zoor0332.xml")

# %%
for bibl in tree.iterfind("//tei:text/tei:back/tei:div[@type = 'bibliography']", namespaces=NAMESPACES): print(bibl)
# Out:
# <Element {http://www.tei-c.org/ns/1.0}div at 0x107caa140>
